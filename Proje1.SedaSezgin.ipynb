# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel('online_retail_II.xlsx', sheet_name='Year 2010-2011', index_col=0)

# %%
df.head()
# Out:
#         StockCode                          Description  Quantity  \
# Invoice
# 536365     85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 536365      71053                  WHITE METAL LANTERN         6
# 536365     84406B       CREAM CUPID HEARTS COAT HANGER         8
# 536365     84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 536365     84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#                 InvoiceDate  Price  Customer ID         Country
# Invoice
# 536365  2010-12-01 08:26:00   2.55      17850.0  United Kingdom
# 536365  2010-12-01 08:26:00   3.39      17850.0  United Kingdom
# 536365  2010-12-01 08:26:00   2.75      17850.0  United Kingdom
# 536365  2010-12-01 08:26:00   3.39      17850.0  United Kingdom
# 536365  2010-12-01 08:26:00   3.39      17850.0  United Kingdom

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 541910 entries, 536365 to 581587
# Data columns (total 7 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   StockCode    541910 non-null  object
#  1   Description  540456 non-null  object
#  2   Quantity     541910 non-null  int64
#  3   InvoiceDate  541910 non-null  datetime64[ns]
#  4   Price        541910 non-null  float64
#  5   Customer ID  406830 non-null  float64
#  6   Country      541910 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(3)
# memory usage: 33.1+ MB

# %%
#Examine the descriptive statistics of the dataset.
df.describe()
# Out:
#             Quantity          Price    Customer ID
# count  541910.000000  541910.000000  406830.000000
# mean        9.552234       4.611138   15287.684160
# std       218.080957      96.759765    1713.603074
# min    -80995.000000  -11062.060000   12346.000000
# 25%         1.000000       1.250000   13953.000000
# 50%         3.000000       2.080000   15152.000000
# 75%        10.000000       4.130000   16791.000000
# max     80995.000000   38970.000000   18287.000000

# %%
print("Veri çerçevesinin boyutu: " + str(np.shape(df)))
# Out:
# Veri çerçevesinin boyutu: (541910, 7)

# %%
#To copy dataFrame.
dfCopy = df.copy()

# %%
print(dfCopy)
# Out:
#         StockCode                          Description  Quantity  \
# Invoice
# 536365     85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 536365      71053                  WHITE METAL LANTERN         6
# 536365     84406B       CREAM CUPID HEARTS COAT HANGER         8
# 536365     84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 536365     84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...           ...                                  ...       ...
# 581587      22899         CHILDREN'S APRON DOLLY GIRL          6
# 581587      23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 581587      23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 581587      22138        BAKING SET 9 PIECE RETROSPOT          3
# 581587       POST                              POSTAGE         1
#
#                 InvoiceDate  Price  Customer ID         Country
# Invoice
# 536365  2010-12-01 08:26:00   2.55      17850.0  United Kingdom
# ...

# %%
dfCopy.reset_index()
# Out:
#        Invoice StockCode                          Description  Quantity  \
# 0       536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1       536365     71053                  WHITE METAL LANTERN         6
# 2       536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3       536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4       536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...        ...       ...                                  ...       ...
# 541905  581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906  581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907  581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908  581587     22138        BAKING SET 9 PIECE RETROSPOT          3
# 541909  581587      POST                              POSTAGE         1
#
#                InvoiceDate  Price  Customer ID         Country
# ...

# %%
#Is there any missing value in DataFrame?
print(dfCopy.isnull().sum())
# Out:
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# Price               0
# Customer ID    135080
# Country             0
# dtype: int64

# %%
print(f"Yes, Customer ID column missing: {dfCopy['Customer ID'].isna().sum()} rows.")
# Out:
# Yes, Customer ID column missing: 135080 rows.

# %%
#Remove missing values.
dfCopy.dropna(thresh=None, subset=None, inplace=True)

# %%
dfCopy
# Out:
#         StockCode                          Description  Quantity  \
# Invoice
# 536365     85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 536365      71053                  WHITE METAL LANTERN         6
# 536365     84406B       CREAM CUPID HEARTS COAT HANGER         8
# 536365     84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 536365     84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...           ...                                  ...       ...
# 581587      22899         CHILDREN'S APRON DOLLY GIRL          6
# 581587      23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 581587      23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 581587      22138        BAKING SET 9 PIECE RETROSPOT          3
# 581587       POST                              POSTAGE         1
#
#                 InvoiceDate  Price  Customer ID         Country
# Invoice
# 536365  2010-12-01 08:26:00   2.55      17850.0  United Kingdom
# ...

# %%
print(dfCopy.isnull().sum())
# Out:
# StockCode      0
# Description    0
# Quantity       0
# InvoiceDate    0
# Price          0
# Customer ID    0
# Country        0
# dtype: int64

# %%
#How many unique products in DataFrame?
df_product = dfCopy.agg({'Description':'nunique'}).sum()
print(df_product)
# Out:
# 3896

# %%
#How many of each product in DataFrame?
dfCopy['Description'].value_counts()
# Out:
# WHITE HANGING HEART T-LIGHT HOLDER    2070
# REGENCY CAKESTAND 3 TIER              1905
# JUMBO BAG RED RETROSPOT               1662
# ASSORTED COLOUR BIRD ORNAMENT         1418
# PARTY BUNTING                         1416
#                                       ...
# WHITE FRANGIPANI HAIR CLIP               1
# BEADED LOVE HEART JEWELLERY SET          1
# LILAC FEATHERS CURTAIN                   1
# BLUE/YELLOW CERAMIC CANDLE HOLDER        1
# NEW BAROQUE B'FLY NECKLACE GREEN         1
# Name: Description, Length: 3896, dtype: int64

# %%
#What are the top 5 most ordered products? 
dfCopy.groupby("Description").agg({"Quantity":"sum"}).sort_values('Quantity',ascending=False).head(5)
# Out:
#                                     Quantity
# Description
# WORLD WAR 2 GLIDERS ASSTD DESIGNS      53215
# JUMBO BAG RED RETROSPOT                45066
# ASSORTED COLOUR BIRD ORNAMENT          35314
# WHITE HANGING HEART T-LIGHT HOLDER     34147
# PACK OF 72 RETROSPOT CAKE CASES        33409

# %%
#Remove the canceled invoices from the dataset.
dfCopy = dfCopy.reset_index() 
dfCopy = dfCopy[~dfCopy["Invoice"].str.contains("C", na=False)]

# %%
dfCopy.shape
# Out:
# (397925, 8)

# %%
dfCopy
# Out:
#        Invoice StockCode                          Description  Quantity  \
# 0       536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1       536365     71053                  WHITE METAL LANTERN         6
# 2       536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3       536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4       536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...        ...       ...                                  ...       ...
# 406825  581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 406826  581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 406827  581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 406828  581587     22138        BAKING SET 9 PIECE RETROSPOT          3
# 406829  581587      POST                              POSTAGE         1
#
#                InvoiceDate  Price  Customer ID         Country
# ...

# %%
#Create a new column 'TotalPrice' in DataFrame.
dfCopy['TotalPrice'] = dfCopy['Price'] * dfCopy['Quantity']

# %%
dfCopy
# Out:
#        Invoice StockCode                          Description  Quantity  \
# 0       536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1       536365     71053                  WHITE METAL LANTERN         6
# 2       536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3       536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4       536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...        ...       ...                                  ...       ...
# 406825  581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 406826  581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 406827  581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 406828  581587     22138        BAKING SET 9 PIECE RETROSPOT          3
# 406829  581587      POST                              POSTAGE         1
#
#                InvoiceDate  Price  Customer ID         Country  TotalPrice
# ...

# %%
#Recency: musterinin son satin alma isleminden bugune kadar gecen sure
#Frequency: musterinin toplam satin alma sayisi
#Monetary: toplam ciro

# %%
dfCopy["InvoiceDate"].max()
# Out:
# Timestamp('2011-12-09 12:50:00')

# %%
today_date = pd.datetime(2011, 12, 11)
# Out:
# <ipython-input-28-1317e1b676c6>:1: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   today_date = pd.datetime(2011, 12, 11)

# %%
#Calculate recency metric.
dfCopy.groupby('Customer ID').agg({'InvoiceDate': lambda date: (today_date - date.max()).days})
# Out:
#              InvoiceDate
# Customer ID
# 12346.0              326
# 12347.0                3
# 12348.0               76
# 12349.0               19
# 12350.0              311
# ...                  ...
# 18280.0              278
# 18281.0              181
# 18282.0                8
# 18283.0                4
# 18287.0               43
#
# [4339 rows x 1 columns]

# %%
#Calculate frequency metric.
dfCopy.groupby('Customer ID').agg({'Invoice': lambda num: num.nunique()})
# Out:
#              Invoice
# Customer ID
# 12346.0            1
# 12347.0            7
# 12348.0            4
# 12349.0            1
# 12350.0            1
# ...              ...
# 18280.0            1
# 18281.0            1
# 18282.0            2
# 18283.0           16
# 18287.0            3
#
# [4339 rows x 1 columns]

# %%
#Calculate monetary metric.
dfCopy.groupby('Customer ID').agg({"TotalPrice": lambda price: price.sum()})
# Out:
#              TotalPrice
# Customer ID
# 12346.0        77183.60
# 12347.0         4310.00
# 12348.0         1797.24
# 12349.0         1757.55
# 12350.0          334.40
# ...                 ...
# 18280.0          180.60
# 18281.0           80.82
# 18282.0          178.05
# 18283.0         2094.88
# 18287.0         1837.28
#
# [4339 rows x 1 columns]

# %%
#Assign your calculated metrics to a variable named rfm.
rfm = dfCopy.groupby('Customer ID').agg({'InvoiceDate': lambda date: (today_date - date.max()).days,
                                                'Invoice': lambda num: num.nunique(),
                                                'TotalPrice': lambda price: price.sum()})

# %%
rfm.head()
# Out:
#              InvoiceDate  Invoice  TotalPrice
# Customer ID
# 12346.0              326        1    77183.60
# 12347.0                3        7     4310.00
# 12348.0               76        4     1797.24
# 12349.0               19        1     1757.55
# 12350.0              311        1      334.40

# %%
#Change the names of the metrics we created as recency, frequency and monetary.
rfm.columns = ['recency', 'frequency', 'monetary']
rfm.head()
# Out:
#              recency  frequency  monetary
# Customer ID
# 12346.0          326          1  77183.60
# 12347.0            3          7   4310.00
# 12348.0           76          4   1797.24
# 12349.0           19          1   1757.55
# 12350.0          311          1    334.40

# %%
#Filter dataset to "monetary>0".
rfm[~((rfm["monetary"]) > 0)]
# Out:
#              recency  frequency  monetary
# Customer ID
# 13256.0           15          1       0.0

# %%
rfm = rfm[(rfm['monetary'] > 0)]
rfm.head()
# Out:
#              recency  frequency  monetary
# Customer ID
# 12346.0          326          1  77183.60
# 12347.0            3          7   4310.00
# 12348.0           76          4   1797.24
# 12349.0           19          1   1757.55
# 12350.0          311          1    334.40

# %%
#Convert recency, frequency and monetary metrics to scores between 1-5 with the help of qcut.
#Record these scores as recency_score, frequency_score and monetary_score.
rfm["recency_score"] = pd.qcut(rfm['recency'], 5, labels=[5, 4, 3, 2, 1])
rfm["frequency_score"] = pd.qcut(rfm['frequency'].rank(method="first"), 5, labels=[1, 2, 3, 4, 5])
rfm["monetary_score"] = pd.qcut(rfm['monetary'], 5, labels=[1, 2, 3, 4, 5])

# %%
rfm.head()
# Out:
#              recency  frequency  monetary recency_score frequency_score  \
# Customer ID
# 12346.0          326          1  77183.60             1               1
# 12347.0            3          7   4310.00             5               5
# 12348.0           76          4   1797.24             2               4
# 12349.0           19          1   1757.55             4               1
# 12350.0          311          1    334.40             1               1
#
#             monetary_score
# Customer ID
# 12346.0                  5
# 12347.0                  5
# 12348.0                  4
# 12349.0                  4
# 12350.0                  2

# %%
#Combine recency_score vs frequency_score into one variable and save as RFM_SCORE.
rfm['RFM_Score'] = rfm['recency_score'].astype("int") + rfm['frequency_score'].astype("int")
rfm.head()
# Out:
#              recency  frequency  monetary recency_score frequency_score  \
# Customer ID
# 12346.0          326          1  77183.60             1               1
# 12347.0            3          7   4310.00             5               5
# 12348.0           76          4   1797.24             2               4
# 12349.0           19          1   1757.55             4               1
# 12350.0          311          1    334.40             1               1
#
#             monetary_score  RFM_Score
# Customer ID
# 12346.0                  5          2
# 12347.0                  5         10
# 12348.0                  4          6
# 12349.0                  4          5
# 12350.0                  2          2

# %%
#Make segment definitions for the RFM_Score.
rfm['RFM_Segment'] = rfm['recency_score'].astype(str) + rfm['frequency_score'].astype(str)
rfm.head()
# Out:
#              recency  frequency  monetary recency_score frequency_score  \
# Customer ID
# 12346.0          326          1  77183.60             1               1
# 12347.0            3          7   4310.00             5               5
# 12348.0           76          4   1797.24             2               4
# 12349.0           19          1   1757.55             4               1
# 12350.0          311          1    334.40             1               1
#
#             monetary_score  RFM_Score RFM_Segment
# Customer ID
# 12346.0                  5          2          11
# 12347.0                  5         10          55
# 12348.0                  4          6          24
# 12349.0                  4          5          41
# 12350.0                  2          2          11

# %%
#Give a name for each RFM segment.
seg_map = {
        r'[1-2][1-2]': 'hibernating',
        r'[1-2][3-4]': 'at_risk',
        r'[1-2]5': 'cant_loose',
        r'3[1-2]': 'about_to_sleep',
        r'33': 'need_attention',
        r'[3-4][4-5]': 'loyal_customers',
        r'41': 'promising',
        r'51': 'new_customers',
        r'[4-5][2-3]': 'potential_loyalists',
        r'5[4-5]': 'champions'
    }

# %%
#Translate all of the RFM scores to RFM segments.
rfm['RFM_Segment'] = rfm['RFM_Segment'].replace(seg_map, regex=True)

# %%
rfm = rfm[["recency", "frequency", "monetary", "RFM_Segment"]]
rfm.head()
# Out:
#              recency  frequency  monetary  RFM_Segment
# Customer ID
# 12346.0          326          1  77183.60  hibernating
# 12347.0            3          7   4310.00    champions
# 12348.0           76          4   1797.24      at_risk
# 12349.0           19          1   1757.55    promising
# 12350.0          311          1    334.40  hibernating

# %%
rfm[["RFM_Segment", "recency", "frequency", "monetary"]].groupby("RFM_Segment").agg(["mean","median","count"])
# Out:
#                         recency               frequency               \
#                            mean median count       mean median count
# RFM_Segment
# about_to_sleep        53.312500     53   352   1.161932      1   352
# at_risk              153.785835    139   593   2.878583      3   593
# cant_loose           132.968254    108    63   8.380952      7    63
# champions              6.361769      5   633  12.417062      8   633
# hibernating          217.605042    219  1071   1.101774      1  1071
# loyal_customers       33.608059     30   819   6.479853      5   819
# need_attention        52.427807     52   187   2.326203      2   187
# new_customers          7.428571      8    42   1.000000      1    42
# potential_loyalists   17.398760     18   484   2.010331      2   484
# promising             23.510638     23    94   1.000000      1    94
#
#                         monetary
#                             mean    median count
# RFM_Segment
# ...

# %%
rfm1 = rfm[["RFM_Segment", "recency", "frequency", "monetary"]].groupby("RFM_Segment").agg(["mean","median","count"])
rfm1.columns = rfm1.columns.droplevel(0)
rfm1.reset_index(inplace=True)
rfm1.columns = ["RFM_Segment","null","null","count","null","null","null","null","null","null"]
rfm1 = rfm1.sort_values(by="count", ascending=False)

# %%
import matplotlib.pyplot as plt

colors = ['#C2C2C2', '#5BADFF', '#33FF99', '#FFAB4B', 
          '#C184FF', '#AD6F33', '#FFFF5B', '#85BBB2',
          '#FF8484', '#33FFFF']

fig1, ax1 = plt.subplots(figsize=(10,7))

ax1.pie(rfm1["count"], labels=rfm1["RFM_Segment"].unique(), colors=colors, 
        explode=[0,0.1,0.1,0.1,0,0,0,0,0,0], autopct='%1.1f%%');

# %%
#Select the Customer IDs of the "loyal_customers" class and get the excel output.
rfm[rfm.RFM_Segment == 'loyal_customers']
# Out:
#              recency  frequency  monetary      RFM_Segment
# Customer ID
# 12352.0           37          8   2506.04  loyal_customers
# 12359.0           58          4   6372.58  loyal_customers
# 12370.0           52          4   3545.69  loyal_customers
# 12380.0           22          4   2724.81  loyal_customers
# 12388.0           16          6   2780.66  loyal_customers
# ...              ...        ...       ...              ...
# 18236.0           30          6    882.24  loyal_customers
# 18257.0           40          8   2337.63  loyal_customers
# 18259.0           25          3   2338.60  loyal_customers
# 18263.0           26          3   1213.16  loyal_customers
# 18287.0           43          3   1837.28  loyal_customers
#
# [819 rows x 4 columns]

# %%
rfm2 = rfm[rfm.RFM_Segment == 'loyal_customers'].reset_index()
rfm2
# Out:
#      Customer ID  recency  frequency  monetary      RFM_Segment
# 0        12352.0       37          8   2506.04  loyal_customers
# 1        12359.0       58          4   6372.58  loyal_customers
# 2        12370.0       52          4   3545.69  loyal_customers
# 3        12380.0       22          4   2724.81  loyal_customers
# 4        12388.0       16          6   2780.66  loyal_customers
# ..           ...      ...        ...       ...              ...
# 814      18236.0       30          6    882.24  loyal_customers
# 815      18257.0       40          8   2337.63  loyal_customers
# 816      18259.0       25          3   2338.60  loyal_customers
# 817      18263.0       26          3   1213.16  loyal_customers
# 818      18287.0       43          3   1837.28  loyal_customers
#
# [819 rows x 5 columns]

# %%
rfm2.to_excel(r'C:\Users\seda.sezgin\OneDrive - Vakko Tekstil ve Hazır Giyim İşl. Sanayi A.Ş\Desktop\VBO\proje1.xlsx', sheet_name='loyal_customers', index = False)
